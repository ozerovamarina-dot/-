# %% [markdown]
# Предсказание цен на квартиры с
# помощью метода линейной регрессии
# <font size=10>

# %%
import pandas as pd
import numpy as np
import random
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('price1.xlsx')
df.head()
# Out:
#    area  price
# 0    28    3.1
# 1    42    3.8
# 2    45    3.9
# 3    52    4.4
# 4    56    4.5

# %%
# %matplotlib inline
plt.scatter(df.area,df.price)

# %%
plt.scatter(df.area, df.price, color='red', marker='^')

# %%
plt.scatter(df.area, df.price, color='red', marker='^')
plt.xlabel('площадь (кв.м.)')
plt.ylabel('стоимость (млн.руб.)')
# Out:
# Text(0, 0.5, 'стоимость (млн.руб.)')

# %%
pip install pandas numpy scikit-learn matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn import linear_model

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[38]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.52747127])

# %%
reg.predict([[120]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([9.38902671])

# %%
reg.coef_,
# Out:
# (array([0.07148238]),)

# %%
reg.intercept_
# Out:
# 0.8111407046647887

# %% [markdown]
# #Таким образом наша модель выглядит следующим образом:
# Стоимость квартиры = 0.07148238 умножить на площадь и плюс
# 0.811140704664788
# y = 0,0715x + 0,81117.

# %%
plt.scatter(df.area, df.price, color='red', marker='^')
plt.xlabel('площадь (кв.м.)')
plt.ylabel('стоимость (млн.руб.)')
plt.plot(df.area, reg.predict(df[['area']]))

# %%
pred = pd.read_excel ('prediction_price.xlsx')

# %%
df = pd.read_excel('prediction_price.xlsx')
df.head(10)
# Out:
#    area
# 0    25
# 1    37
# 2    40
# 3    58
# 4    61
# 5    67
# 6    72
# 7    85
# 8    96
# 9   105

# %%
pred
# Out:
#     area
# 0     25
# 1     37
# 2     40
# 3     58
# 4     61
# 5     67
# 6     72
# 7     85
# 8     96
# 9    105
# 10   118

# %%
reg.predict(pred)
# Out:
# array([2.59820029, 3.45598889, 3.67043604, 4.95711894, 5.17156609,
#        5.60046039, 5.95787231, 6.88714329, 7.67344951, 8.31679096,
#        9.24606194])

# %%
p = reg.predict(pred)

# %%
pred['predicted prices'] = p

# %%
pred
# Out:
#     area  predicted prices
# 0     25          2.598200
# 1     37          3.455989
# 2     40          3.670436
# 3     58          4.957119
# 4     61          5.171566
# 5     67          5.600460
# 6     72          5.957872
# 7     85          6.887143
# 8     96          7.673450
# 9    105          8.316791
# 10   118          9.246062

# %%
pred.to_excel("new.xlsx")
